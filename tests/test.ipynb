# %%
import torch

# %%
x = torch.randn(2, 3)
x
# Out:
# tensor([[ 1.8905,  0.2030,  0.4855],
#         [-1.7369, -0.1918, -1.1902]])

# %%
y = torch.max(x, dim = 1)[0].unsqueeze(1)
y
# Out:
# tensor([[ 1.8905],
#         [-0.1918]])

# %%
x - y
# Out:
# tensor([[ 0.0000, -1.6875, -1.4050],
#         [-1.5452,  0.0000, -0.9984]])

# %%
z = torch.exp(x - y)
z
# Out:
# tensor([[1.0000, 0.1850, 0.2454],
#         [0.2133, 1.0000, 0.3685]])

# %%
torch.sum(z, dim = 1).unsqueeze(1)
# Out:
# tensor([[1.4304],
#         [1.5817]])

# %%
torch.ones(3,1)
# Out:
# tensor([[1.],
#         [1.],
#         [1.]])
